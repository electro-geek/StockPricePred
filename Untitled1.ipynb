# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading through many csv files
import glob
import os
path = os.getcwd() + "/individual_stocks_5yr"
csv_files = glob.glob(path + '*/.csv')
df_list = (pd.read_csv(file) for file in csv_files)
#concatenate all the dataframe
df = pd.concat(map(pd.read_csv, glob.glob(path + "/*.csv")))

# %%
path = os.getcwd() + "/individual_stocks_5yr"
csv_files = glob.glob(path + '*/.csv')
df_list = (pd.read_csv(file) for file in csv_files)

# %%
print(df_list)
# Out:
# <generator object <genexpr> at 0x000001AEE97D0CF0>

# %%
os.listdir(path)
# Out:
# ['.DS_Store',
#  'AAL_data.csv',
#  'AAPL_data.csv',
#  'AAP_data.csv',
#  'ABBV_data.csv',
#  'ABC_data.csv',
#  'ABT_data.csv',
#  'ACN_data.csv',
#  'ADBE_data.csv',
#  'ADI_data.csv',
#  'ADM_data.csv',
#  'ADP_data.csv',
#  'ADSK_data.csv',
#  'ADS_data.csv',
#  'AEE_data.csv',
#  'AEP_data.csv',
#  'AES_data.csv',
#  'AET_data.csv',
#  'AFL_data.csv',
#  'AGN_data.csv',
#  'AIG_data.csv',
#  'AIV_data.csv',
#  'AIZ_data.csv',
#  'AJG_data.csv',
#  'AKAM_data.csv',
#  'ALB_data.csv',
#  'ALGN_data.csv',
#  'ALK_data.csv',
#  'ALLE_data.csv',
#  'ALL_data.csv',
#  'ALXN_data.csv',
#  'AMAT_data.csv',
#  'AMD_data.csv',
#  'AME_data.csv',
#  'AMGN_data.csv',
#  'AMG_data.csv',
#  'AMP_data.csv',
#  'AMT_data.csv',
#  'AMZN_data.csv',
#  'ANDV_data.csv',
#  'ANSS_data.csv',
#  'ANTM_data.csv',
#  'AON_data.csv',
#  'AOS_data.csv',
#  'APA_data.csv',
#  'APC_data.csv',
#  'APD_data.csv',
#  'APH_data.csv',
#  'APTV_data.csv',
#  'ARE_data.csv',
#  'ARNC_data.csv',
# ...

# %%
list1 = os.listdir(path)

# %%
list1
# Out:
# ['.DS_Store',
#  'AAL_data.csv',
#  'AAPL_data.csv',
#  'AAP_data.csv',
#  'ABBV_data.csv',
#  'ABC_data.csv',
#  'ABT_data.csv',
#  'ACN_data.csv',
#  'ADBE_data.csv',
#  'ADI_data.csv',
#  'ADM_data.csv',
#  'ADP_data.csv',
#  'ADSK_data.csv',
#  'ADS_data.csv',
#  'AEE_data.csv',
#  'AEP_data.csv',
#  'AES_data.csv',
#  'AET_data.csv',
#  'AFL_data.csv',
#  'AGN_data.csv',
#  'AIG_data.csv',
#  'AIV_data.csv',
#  'AIZ_data.csv',
#  'AJG_data.csv',
#  'AKAM_data.csv',
#  'ALB_data.csv',
#  'ALGN_data.csv',
#  'ALK_data.csv',
#  'ALLE_data.csv',
#  'ALL_data.csv',
#  'ALXN_data.csv',
#  'AMAT_data.csv',
#  'AMD_data.csv',
#  'AME_data.csv',
#  'AMGN_data.csv',
#  'AMG_data.csv',
#  'AMP_data.csv',
#  'AMT_data.csv',
#  'AMZN_data.csv',
#  'ANDV_data.csv',
#  'ANSS_data.csv',
#  'ANTM_data.csv',
#  'AON_data.csv',
#  'AOS_data.csv',
#  'APA_data.csv',
#  'APC_data.csv',
#  'APD_data.csv',
#  'APH_data.csv',
#  'APTV_data.csv',
#  'ARE_data.csv',
#  'ARNC_data.csv',
# ...

# %%
list1.remove('.DS_Store')

# %%
list1
# Out:
# ['AAL_data.csv',
#  'AAPL_data.csv',
#  'AAP_data.csv',
#  'ABBV_data.csv',
#  'ABC_data.csv',
#  'ABT_data.csv',
#  'ACN_data.csv',
#  'ADBE_data.csv',
#  'ADI_data.csv',
#  'ADM_data.csv',
#  'ADP_data.csv',
#  'ADSK_data.csv',
#  'ADS_data.csv',
#  'AEE_data.csv',
#  'AEP_data.csv',
#  'AES_data.csv',
#  'AET_data.csv',
#  'AFL_data.csv',
#  'AGN_data.csv',
#  'AIG_data.csv',
#  'AIV_data.csv',
#  'AIZ_data.csv',
#  'AJG_data.csv',
#  'AKAM_data.csv',
#  'ALB_data.csv',
#  'ALGN_data.csv',
#  'ALK_data.csv',
#  'ALLE_data.csv',
#  'ALL_data.csv',
#  'ALXN_data.csv',
#  'AMAT_data.csv',
#  'AMD_data.csv',
#  'AME_data.csv',
#  'AMGN_data.csv',
#  'AMG_data.csv',
#  'AMP_data.csv',
#  'AMT_data.csv',
#  'AMZN_data.csv',
#  'ANDV_data.csv',
#  'ANSS_data.csv',
#  'ANTM_data.csv',
#  'AON_data.csv',
#  'AOS_data.csv',
#  'APA_data.csv',
#  'APC_data.csv',
#  'APD_data.csv',
#  'APH_data.csv',
#  'APTV_data.csv',
#  'ARE_data.csv',
#  'ARNC_data.csv',
#  'ATVI_data.csv',
# ...

# %%
for i in list1:
    x = pd.read_csv(os.getcwd() + "/individual_stocks_5yr"+"/"+i)
    for j in x.iloc[:,1:-1]:
        mean_value = x[j].mean()
        x = x.fillna(value = mean_value, inplace = True)
    print(x.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MRITUN~1\AppData\Local\Temp/ipykernel_13024/602815654.py in <module>
#       2     x = pd.read_csv(os.getcwd() + "/individual_stocks_5yr"+"/"+i)
#       3     for j in x.iloc[:,1:-1]:
# ----> 4         mean_value = x[j].mean()
#       5         x = x.fillna(value = mean_value, inplace = True)
#       6     print(x.isnull().sum())
#
# TypeError: 'NoneType' object is not subscriptable

# %%
for i in list1:
    x = pd.read_csv(os.getcwd() + "/individual_stocks_5yr"+"/"+i)
    print(x.isnull().sum())
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# ...

# %%
ndf = pd.read_csv(os.getcwd() + "/individual_stocks_5yr"+"/"'NDAQ_data.csv')

# %%
ndf.head()
# Out:
#          date   open     high     low  close   volume  Name
# 0  2013-02-08  29.40  29.4900  29.142  29.47   863756  NDAQ
# 1  2013-02-11  29.49  32.1499  29.320  30.38  6707438  NDAQ
# 2  2013-02-12  31.33  31.6500  29.930  30.55  3384949  NDAQ
# 3  2013-02-13  30.44  31.7000  30.440  31.65  3210667  NDAQ
# 4  2013-02-14  31.51  31.5100  30.410  30.60  5653021  NDAQ

# %%
ndf.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
for i in ndf['date']:
    y = i.split("-")
    total = int(y[0]+y[1]+y[2])
    ndf = ndf.replace(i,total)

# %%
ndf.head()
# Out:
#        date   open     high     low  close   volume  Name
# 0  20130208  29.40  29.4900  29.142  29.47   863756  NDAQ
# 1  20130211  29.49  32.1499  29.320  30.38  6707438  NDAQ
# 2  20130212  31.33  31.6500  29.930  30.55  3384949  NDAQ
# 3  20130213  30.44  31.7000  30.440  31.65  3210667  NDAQ
# 4  20130214  31.51  31.5100  30.410  30.60  5653021  NDAQ

# %%
for i in ndf['date']:
    y = i.split("-")
    total = int(y[0]+y[1]+y[2])
    print(total)
# Out:
# 20130208
# 20130211
# 20130212
# 20130213
# 20130214
# 20130215
# 20130219
# 20130220
# 20130221
# 20130222
# 20130225
# 20130226
# 20130227
# 20130228
# 20130301
# 20130304
# 20130305
# 20130306
# 20130307
# 20130308
# 20130311
# 20130312
# 20130313
# 20130314
# 20130315
# 20130318
# 20130319
# 20130320
# 20130321
# 20130322
# 20130325
# 20130326
# 20130327
# 20130328
# 20130401
# 20130402
# 20130403
# 20130404
# 20130405
# 20130408
# 20130409
# 20130410
# 20130411
# 20130412
# 20130415
# 20130416
# 20130417
# 20130418
# 20130419
# 20130422
# 20130423
# 20130424
# 20130425
# 20130426
# 20130429
# 20130430
# 20130501
# 20130502
# 20130503
# 20130506
# 20130507
# 20130508
# 20130509
# 20130510
# 20130513
# 20130514
# 20130515
# 20130516
# 20130517
# 20130520
# 20130521
# 20130522
# 20130523
# 20130524
# 20130528
# 20130529
# 20130530
# 20130531
# 20130603
# 20130604
# 20130605
# 20130606
# 20130607
# 20130610
# 20130611
# 20130612
# 20130613
# 20130614
# 20130617
# 20130618
# ...
